# %%
import pandas as pd
import numpy as np
import os
import re
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud, ImageColorGenerator
from nltk.corpus import stopwords
import nltk

# %%
TRAIN_PATH = os.path.join(os.getcwd(), 'data', 'train.csv')
TEST_PATH = os.path.join(os.getcwd(), 'data', 'test.csv')
VALIDATE_PATH = os.path.join(os.getcwd(), 'data', 'validate.csv')

RANDOM = 42

# %% [markdown]
# ## Data Loading

# %%
df = pd.read_csv(TRAIN_PATH)
df
# Out:
#      label                                            message
# 0      ham                       Oh k. . I will come tomorrow
# 1      ham                        What you doing?how are you?
# 2     spam  I am hot n horny and willing I live local to y...
# 3      ham                          How much is torch in 9ja.
# 4      ham  Baaaaaaaabe! Wake up ! I miss you ! I crave yo...
# ...    ...                                                ...
# 1165  spam  HOT LIVE FANTASIES call now 08707509020 Just 2...
# 1166   ham  Wishing you and your family Merry "X" mas and ...
# 1167   ham    Change again... It's e one next to escalator...
# 1168  spam  -PLS STOP bootydelious (32/F) is inviting you ...
# 1169   ham                             Then mum's repent how?
#
# [1170 rows x 2 columns]

# %% [markdown]
# ## Data Exploration

# %%
df.describe()
# Out:
#        label                                            message
# count   1170                                               1170
# unique     2                                               1141
# top      ham  I cant pick the phone right now. Pls send a me...
# freq     998                                                  5

# %%
df.isna().sum()
# Out:
# label      0
# message    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df[df.duplicated()]
# Out:
#      label                                            message
# 127    ham  I cant pick the phone right now. Pls send a me...
# 152    ham                                                Ok.
# 297    ham                             Sorry, I'll call later
# 318    ham                                                Ok.
# 376    ham                   No calls..messages..missed calls
# 407    ham  I cant pick the phone right now. Pls send a me...
# 449    ham  wiskey Brandy Rum Gin Beer Vodka Scotch Shampa...
# 552    ham              Ya very nice. . .be ready on thursday
# 578    ham                       Love you aathi..love u lot..
# 597    ham  Today is ACCEPT DAY..U Accept me as? Brother S...
# 645    ham  I cant pick the phone right now. Pls send a me...
# 690   spam  Your free ringtone is waiting to be collected....
# 704    ham                             Sorry, I'll call later
# 743   spam  Camera - You are awarded a SiPix Digital Camer...
# 773    ham                             Sorry, I'll call later
# 832   spam  Please call our customer service representativ...
# 839    ham     As usual..iam fine, happy &amp; doing well..:)
# 863    ham               Ok.ok ok..then..whats ur todays plan
# 866    ham  A bit of Ur smile is my hppnss, a drop of Ur t...
# 867    ham  I cant pick the phone right now. Pls send a me...
# 896    ham  7 wonders in My WORLD 7th You 6th Ur style 5th...
# 979    ham                           I'm at home. Please call
# 995   spam  U can WIN £100 of Music Gift Vouchers every we...
# 1032   ham                         I am on the way to ur home
# 1060   ham  Hurt me... Tease me... Make me cry... But in t...
# 1065  spam  WIN: We have a winner! Mr. T. Foley won an iPo...
# 1103   ham               You will be in the place of that man
# 1115   ham  The Xmas story is peace.. The Xmas msg is love...
# 1164   ham  Hi Dear Call me its urgnt. I don't know whats ...

# %% [markdown]
# ## Data Visualization

# %%
df['messageLen'] = df.message.apply(lambda x: len(x))

fig, ax = plt.subplots(figsize=(12, 8))
sns.histplot(data=df, x="messageLen", hue="label")
plt.title("Message Length Histogram")
plt.show()

# %%
# word cloud without cleaning
def showWC(label, colMessage):
    wc = WordCloud(
        background_color='white',
        max_words=200
    )

    wc.generate(' '.join(text for text in df.loc[df['label'] == label, colMessage]))
    plt.figure(figsize=(12, 8))
    plt.title(
        f'Top words for {label} messages', 
        fontdict={'size': 22,  
        'verticalalignment': 'bottom'}
    )
    plt.imshow(wc)
    plt.axis("off")
    plt.show()

# %%
showWC('ham', 'message')

# %%
showWC('spam', 'message')

# %% [markdown]
# ## Data Cleaning

# %%
def clean_text(text):
    # lowercase whole string
    text = str(text).lower()
    
    # remove special character & number
    text = re.sub('[^A-Za-z]+', ' ', text)
    return text

df['clean_text'] = df.message.apply(clean_text)

# %%
df.clean_text.duplicated().sum()
# Out:
# 34

# %%
showWC('ham', 'clean_text')
showWC('spam', 'clean_text')

# %%
# additional resources
nltk.download('stopwords')

def remove_stopwords(text):
    stop_words = stopwords.words('english')
    # after inspecting, add our own stopwords
    # more_stopwords = ['u', 'ur']
    # stop_words += more_stopwords

    text = ' '.join(word for word in text.split(' ') if word not in stop_words)
    return text

df['clean_stopwords'] = df.clean_text.apply(remove_stopwords)
df
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\isaac\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#      label                                            message  messageLen  \
# 0      ham                       Oh k. . I will come tomorrow          28
# 1      ham                        What you doing?how are you?          27
# 2     spam  I am hot n horny and willing I live local to y...         155
# 3      ham                          How much is torch in 9ja.          25
# 4      ham  Baaaaaaaabe! Wake up ! I miss you ! I crave yo...          60
# ...    ...                                                ...         ...
# 1165  spam  HOT LIVE FANTASIES call now 08707509020 Just 2...         101
# 1166   ham  Wishing you and your family Merry "X" mas and ...          73
# 1167   ham    Change again... It's e one next to escalator...          47
# 1168  spam  -PLS STOP bootydelious (32/F) is inviting you ...         152
# 1169   ham                             Then mum's repent how?          22
#
#                                              clean_text  \
# 0                             oh k i will come tomorrow
# 1                           what you doing how are you
# 2     i am hot n horny and willing i live local to y...
# 3                              how much is torch in ja
# 4     baaaaaaaabe wake up i miss you i crave you i n...
# ...                                                 ...
# 1165  hot live fantasies call now just p per min ntt...
# 1166  wishing you and your family merry x mas and ha...
# 1167         change again it s e one next to escalator
# 1168   pls stop bootydelious f is inviting you to be...
# 1169                             then mum s repent how
#
#                                         clean_stopwords
# 0                                    oh k come tomorrow
# 1
# 2     hot n horny willing live local text reply hear...
# 3                                        much torch ja
# 4                     baaaaaaaabe wake miss crave need
# ...                                                 ...
# 1165  hot live fantasies call p per min ntt ltd po b...
# 1166  wishing family merry x mas happy new year adva...
# 1167                       change e one next escalator
# 1168   pls stop bootydelious f inviting friend reply...
# 1169                                        mum repent
#
# [1170 rows x 5 columns]

# %%
showWC('ham', 'clean_stopwords')
showWC('spam', 'clean_stopwords')

# %%
def stemm_text(text):
    stemmer = nltk.SnowballStemmer('english')
    text = ' '.join(stemmer.stem(word) for word in text.split(' '))
    return text

df['clean_stemm'] = df.clean_stopwords.apply(stemm_text)
df
# Out:
#      label                                            message  messageLen  \
# 0      ham                       Oh k. . I will come tomorrow          28
# 1      ham                        What you doing?how are you?          27
# 2     spam  I am hot n horny and willing I live local to y...         155
# 3      ham                          How much is torch in 9ja.          25
# 4      ham  Baaaaaaaabe! Wake up ! I miss you ! I crave yo...          60
# ...    ...                                                ...         ...
# 1165  spam  HOT LIVE FANTASIES call now 08707509020 Just 2...         101
# 1166   ham  Wishing you and your family Merry "X" mas and ...          73
# 1167   ham    Change again... It's e one next to escalator...          47
# 1168  spam  -PLS STOP bootydelious (32/F) is inviting you ...         152
# 1169   ham                             Then mum's repent how?          22
#
#                                              clean_text  \
# 0                             oh k i will come tomorrow
# 1                           what you doing how are you
# 2     i am hot n horny and willing i live local to y...
# 3                              how much is torch in ja
# 4     baaaaaaaabe wake up i miss you i crave you i n...
# ...                                                 ...
# 1165  hot live fantasies call now just p per min ntt...
# 1166  wishing you and your family merry x mas and ha...
# 1167         change again it s e one next to escalator
# 1168   pls stop bootydelious f is inviting you to be...
# 1169                             then mum s repent how
#
#                                         clean_stopwords  \
# 0                                    oh k come tomorrow
# 1
# 2     hot n horny willing live local text reply hear...
# 3                                        much torch ja
# 4                     baaaaaaaabe wake miss crave need
# ...                                                 ...
# 1165  hot live fantasies call p per min ntt ltd po b...
# 1166  wishing family merry x mas happy new year adva...
# 1167                       change e one next escalator
# 1168   pls stop bootydelious f inviting friend reply...
# 1169                                        mum repent
#
#                                             clean_stemm
# 0                                    oh k come tomorrow
# 1
# 2     hot n horni will live local text repli hear st...
# 3                                        much torch ja
# 4                      baaaaaaaab wake miss crave need
# ...                                                 ...
# 1165  hot live fantasi call p per min ntt ltd po box...
# 1166     wish famili merri x mas happi new year advanc
# 1167                            chang e one next escal
# 1168   pls stop bootydeli f invit friend repli yes s...
# 1169                                        mum repent
#
# [1170 rows x 6 columns]

# %%
showWC('ham', 'clean_stemm')
showWC('spam', 'clean_stemm')

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier

# %%
X = df['clean_stemm']
y = df['label']
y = LabelEncoder().fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=RANDOM)

# %%
# initialize pipeline
pipe = Pipeline([
    ('bag_of_word', CountVectorizer()),
    ('tfid', TfidfTransformer()),
    ('xgb', XGBClassifier())
])

# fitting
pipe.fit(X_train, y_train)
print("Training\n", pipe.score(X_train, y_train))
print("Test\n", pipe.score(X_test, y_test))
# Out:
# Training
#  0.9902319902319903
# Test
#  0.9601139601139601

# %% [markdown]
# Looks good, but this do not include test sets and validation sets. In addition, to follow the DRY rules, lets try implement usage of function or maybe whole in a pipeline.
